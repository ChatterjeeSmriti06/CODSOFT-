# %%
import random

print('Winning rules of the game ROCK PAPER SCISSORS are :\n' + "Rock vs Paper -> Paper wins \n"+ "Rock vs Scissors -> Rock wins \n" + "Paper vs Scissors -> Scissor wins \n")
 
while True:
     
    print("Enter your choice \n 1 - Rock \n 2 - Paper \n 3 - Scissors \n")
    c=int(input("Enter your choice :"))
         
    if c == 1:
        choice_name= 'Rock'
    elif c == 2:
        choice_name= 'Paper'
    elif c==3:
        choice_name= 'Scissors'
    else:
        print('Enter a valid choice')
    print('User choice: \n',choice_name)
    print('Computers Turn....')
     
    comp_c = random.randint(1,3)
     
    while comp_c== c:
        comp_c= random.randint(1,3)
         
    if comp_c== 1:
        comp_choice_name = 'rock'
    elif comp_c == 2:
        comp_choice_name = 'paper'
    else:
        comp_choice_name = 'scissor'
    print("Computer choice is \n", comp_choice_name)
    print(choice_name,'Vs',comp_choice_name)
    
    if c== comp_c:
        print('Its a Draw',end="")
        result="DRAW"    
    if (c==1 and comp_c==2):
        print('paper wins =>',end="")
        result='papeR'
    elif (c==2 and comp_c==1):
        print('paper wins =>',end="")
        result='Paper'
         
       
    if (c==1 and comp_c==3):
        print('Rock wins =>\n',end= "")
        result='Rock'
    elif (c==3 and comp_choice==1):
        print('Rock wins =>\n',end= "")
        result='Rock'
         
    if (c==2 and comp_c==3):
        print('Scissors wins =>',end="")
        result='Scissors'
    elif (c==3 and comp_c==2):
        print('Scissors wins =>',end="")
        result='Rock'
    if result == 'DRAW':
        print("\n Its a tie")
    if result == choice_name:
        print(" \n You win ")
    else:
        print("\n Computer wins ")
    print("Do you want to play again? (Y/N)")
    ans = input().lower()
    if ans =='n':
        break
    print("Thanks for playing")
# Out:
# Winning rules of the game ROCK PAPER SCISSORS are :
# Rock vs Paper -> Paper wins
# Rock vs Scissors -> Rock wins
# Paper vs Scissors -> Scissor wins
#
# Enter your choice
#  1 - Rock
#  2 - Paper
#  3 - Scissors
#
# Enter your choice :1
# User choice:
#  Rock
# Computers Turn....
# Computer choice is
#  paper
# Rock Vs paper
# paper wins =>
#  Computer wins
# Do you want to play again? (Y/N)
# y
# Thanks for playing
# Enter your choice
#  1 - Rock
#  2 - Paper
#  3 - Scissors
#
# Enter your choice :2
# User choice:
#  Paper
# Computers Turn....
# Computer choice is
#  scissor
# Paper Vs scissor
# Scissors wins =>
#  Computer wins
# Do you want to play again? (Y/N)
# y
# Thanks for playing
# Enter your choice
#  1 - Rock
#  2 - Paper
#  3 - Scissors
#
# Enter your choice :3
# User choice:
#  Scissors
# Computers Turn....
# Computer choice is
#  rock
# Scissors Vs rock
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 49
#      47     print('Rock wins =>\n',end= "")
#      48     result='Rock'
# ---> 49 elif (c==3 and comp_choice==1):
#      50     print('Rock wins =>\n',end= "")
#      51     result='Rock'
#
# NameError: name 'comp_choice' is not defined
